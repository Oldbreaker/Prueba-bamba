# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/amdat/Desktop/insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# En esta parte podemos ver la descripcion de todos los valores númericos viendo su media, desviación estandar y los cuartiles así como también maximos y minimos de todas las tablas númericas.

# %%
 df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.set(style='ticks',color_codes=True)
g=sns.pairplot(df,hue='smoker',palette='Spectral')

# %%
sns.set(style='ticks',color_codes=True)
g=sns.pairplot(df,hue='sex',palette='Spectral')

# %%
sns.set(style='ticks',color_codes=True)
g=sns.pairplot(df,hue='region',palette='Spectral')

# %% [markdown]
# En las diferentes graficas que podemos ver encontramos si puede verse alguna relación con las variables para poder ver si afectaria a nuestro modelo alguna de estas como categorías.

# %% [markdown]
# ## Propuesta Modelo

# %% [markdown]
# En definitiva podemos ver que la variable dependiente sería los charges y nuestras variables independientes serian age,bmi,children.
# Podriamos hacer un modelo de regresión lineal usando alguna libreria de python como scikit-learn para poder pasar nuestros datos a ese modelo y ver si nos da un accuracy score propio para este mismo y poder tener un prediccion favorable o erronea.
# Esto sería solo como un caso especifico pero tambien se podría escoger 2 modelos más aparte del lineal como podrían ser arboles de clasificación o bayesianos o cualquier modelo en el caul uno se sienta que domina o es más favorable para el uso de este problema.
# Se haría un proyección por cada modelo y podriamos comparar cual de ellos se adecua más al proceso que necesitamos y nos da un mejor score de fiabilidad.
